# %% [markdown]
# #### Part 3: Integration of R and Python
#
# - Working now with Python Kernel
# - Can integrate R code and pass variables between two languages
# - Python has lots of additional functionalities for data science!

# %%
# %load_ext rpy2.ipython

# %%
# %R require(ggplot2)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Loading required package: ggplot2
#
#   warnings.warn(x, RRuntimeWarning)
# array([1], dtype=int32)

# %%
import pandas as pd
df = pd.DataFrame({
        'Letter': ['a', 'a', 'a', 'b', 'b', 'b', 'c', 'c', 'c'],
        'X': [4, 3, 5, 2, 1, 7, 7, 5, 9],
        'Y': [0, 4, 3, 6, 7, 10, 11, 9, 13],
        'Z': [1, 2, 3, 1, 2, 3, 1, 2, 3]
    })

# %%
# %%R -i df -o newVar
# print(df)
# newVar <- df$X+df$Y
# ggplot(data = df) + geom_point(aes(x = X, y= Y, color = Letter, size = Z))
# Out:
#   Letter X  Y Z
# 0      a 4  0 1
# 1      a 3  4 2
# 2      a 5  3 3
# 3      b 2  6 1
# 4      b 1  7 2
# 5      b 7 10 3
# 6      c 7 11 1
# 7      c 5  9 2
# 8      c 9 13 3

# %%
# %%R
# print(newVar)
# Out:
# [1]  4  7  8  8  8 17 18 14 22

# %%
print(newVar)
# Out:
# [ 4  7  8  8  8 17 18 14 22]

# %% [markdown]
# #### Versatility of python
# - Importing videos

# %%
from IPython.display import YouTubeVideo
# a talk about IPython at Sage Days at U. Washington, Seattle.
# Video credit: William Stein.
YouTubeVideo('HQZ3-OD0ml0')

# %% [markdown]
# - Interactive graphics with Bokeh

# %%
import numpy as np
from bokeh.plotting import figure, output_notebook, show
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]
output_notebook()
TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,tap,previewsave,box_select,poly_select,lasso_select"

p = figure(tools=TOOLS)
p.scatter(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)
show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7b61d6bc-bab0-4a50-bca9-b1b3885e8ff7">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="6c7ed126-0d88-46e6-836b-ed193a875a89"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
# ...
